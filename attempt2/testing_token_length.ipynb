# %%
# %pip install -U datasets
# Out:
# Requirement already satisfied: datasets in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (3.1.0)
# Requirement already satisfied: filelock in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from datasets) (3.16.1)
# Requirement already satisfied: numpy>=1.17 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from datasets) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from datasets) (0.3.6)
# Requirement already satisfied: pandas in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from datasets) (1.5.1)
# Requirement already satisfied: requests>=2.32.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from datasets) (4.67.0)
# Requirement already satisfied: xxhash in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from datasets) (3.2.0)
# Requirement already satisfied: multiprocess<0.70.17 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from datasets) (0.70.14)
# Requirement already satisfied: fsspec<=2024.9.0,>=2023.1.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets) (2024.9.0)
# Requirement already satisfied: aiohttp in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from datasets) (3.10.10)
# Requirement already satisfied: huggingface-hub>=0.23.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from datasets) (0.26.2)
# Requirement already satisfied: packaging in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from datasets) (6.0.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from aiohttp->datasets) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from aiohttp->datasets) (1.3.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from aiohttp->datasets) (1.17.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from huggingface-hub>=0.23.0->datasets) (4.8.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests>=2.32.2->datasets) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests>=2.32.2->datasets) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests>=2.32.2->datasets) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests>=2.32.2->datasets) (2022.9.24)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas->datasets) (2022.6)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)
# Requirement already satisfied: propcache>=0.2.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from yarl<2.0,>=1.12.0->aiohttp->datasets) (0.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from transformers import AutoTokenizer
from datasets import load_dataset
import numpy as np

# %%
# Load the model's tokenizer
model_name = "NousResearch/Llama-2-7b-hf"
tokenizer = AutoTokenizer.from_pretrained(model_name)

# Load dataset
dataset = load_dataset("DONG19/EffiBench")
train_data = dataset["train"]

# Initialize lists to store lengths
desc_lengths = []
soln_lengths = []
combined_lengths = []

# %%
# Process each example
for example in train_data:
    # Get raw text
    desc = example["markdown_description"]
    soln = example["canonical_solution"]
    combined = f"### Input:\n{desc}\n\n### Output:\n{soln}\n\n### End"
    
    # Tokenize without padding
    desc_tokens = tokenizer(desc, truncation=False, padding=False)
    soln_tokens = tokenizer(soln, truncation=False, padding=False)
    combined_tokens = tokenizer(combined, truncation=False, padding=False)
    
    # Store lengths
    desc_lengths.append(len(desc_tokens["input_ids"]))
    soln_lengths.append(len(soln_tokens["input_ids"]))
    combined_lengths.append(len(combined_tokens["input_ids"]))
    
    # Print extremely long examples for inspection
    if len(combined_tokens["input_ids"]) > 1000:
        print("\nFound very long example:")
        print(f"Description length: {len(desc_tokens['input_ids'])} tokens")
        print(f"Solution length: {len(soln_tokens['input_ids'])} tokens")
        print(f"Combined length: {len(combined_tokens['input_ids'])} tokens")
        print("\nDescription preview (first 100 chars):", desc[:100])
        print("Solution preview (first 100 chars):", soln[:100])
# Out:
# Found very long example:
# Description length: 563 tokens
# Solution length: 429 tokens
# Combined length: 1006 tokens
#
# Description preview (first 100 chars):
# A **transformation sequence** from word `beginWord` to word `endWord` using a dictionary `wordList`
# Solution preview (first 100 chars): class Solution:
#     def findLadders(
#         self, beginWord: str, endWord: str, wordList: List[str]
#
# Found very long example:
# Description length: 752 tokens
# Solution length: 252 tokens
# Combined length: 1018 tokens
#
# Description preview (first 100 chars):
# A city's **skyline** is the outer contour of the silhouette formed by all the buildings in that cit
# Solution preview (first 100 chars): from queue import PriorityQueue
#
#
# class Solution:
#     def getSkyline(self, buildings: List[List[int]
#
# Found very long example:
# Description length: 1109 tokens
# Solution length: 244 tokens
# Combined length: 1367 tokens
#
# Description preview (first 100 chars):
# Suppose we have a file system that stores both files and directories. An example of one system is r
# Solution preview (first 100 chars): class Solution:
#     def lengthLongestPath(self, input: str) -> int:
#         i, n = 0, len(input)
#
#
# Found very long example:
# Description length: 821 tokens
# Solution length: 269 tokens
# Combined length: 1104 tokens
#
# Description preview (first 100 chars):
# You are given an array of variable pairs `equations` and an array of real numbers `values`, where `
# Solution preview (first 100 chars): class Solution:
#     def calcEquation(
#         self, equations: List[List[str]], values: List[float],
#
# Found very long example:
# Description length: 866 tokens
# Solution length: 415 tokens
# Combined length: 1295 tokens
#
# Description preview (first 100 chars):
# There is an `m x n` rectangular island that borders both the **Pacific Ocean** and **Atlantic Ocean
# Solution preview (first 100 chars): class Solution:
#     def pacificAtlantic(self, heights: List[List[int]]) -> List[List[int]]:
#
#
# Found very long example:
# Description length: 639 tokens
# Solution length: 722 tokens
# Combined length: 1375 tokens
#
# Description preview (first 100 chars):
# The **median** is the middle value in an ordered integer list. If the size of the list is even, the
# Solution preview (first 100 chars): class MedianFinder:
#     def __init__(self, k: int):
#         self.k = k
#         self.small = []
#
#
# Found very long example:
# Description length: 803 tokens
# Solution length: 247 tokens
# Combined length: 1064 tokens
#
# Description preview (first 100 chars):
# There is a ball in a `maze` with empty spaces (represented as `0`) and walls (represented as `1`).
# Solution preview (first 100 chars): class Solution:
#     def hasPath(
#         self, maze: List[List[int]], start: List[int], destination:
#
# Found very long example:
# Description length: 1058 tokens
# Solution length: 414 tokens
# Combined length: 1486 tokens
#
# Description preview (first 100 chars):
# There is a ball in a `maze` with empty spaces (represented as `0`) and walls (represented as `1`).
# Solution preview (first 100 chars): class Solution:
#     def findShortestWay(
#         self, maze: List[List[int]], ball: List[int], hole:
#
# Found very long example:
# Description length: 895 tokens
# Solution length: 295 tokens
# Combined length: 1204 tokens
#
# Description preview (first 100 chars):
# There is a ball in a `maze` with empty spaces (represented as `0`) and walls (represented as `1`).
# Solution preview (first 100 chars): class Solution:
#     def shortestDistance(
#         self, maze: List[List[int]], start: List[int], des
#
# Found very long example:
# Description length: 873 tokens
# Solution length: 300 tokens
# Combined length: 1187 tokens
#
# Description preview (first 100 chars):
# Let's play the minesweeper game ([Wikipedia](https://en.wikipedia.org/wiki/Minesweeper_(video_game)
# Solution preview (first 100 chars): class Solution:
#     def updateBoard(self, board: List[List[str]], click: List[int]) -> List[List[str
#
# Found very long example:
# Description length: 1176 tokens
# Solution length: 210 tokens
# Combined length: 1400 tokens
#
# Description preview (first 100 chars):
# LeetCode wants to give one of its best employees the option to travel among `n` cities to collect a
# Solution preview (first 100 chars): class Solution:
#     def maxVacationDays(self, flights: List[List[int]], days: List[List[int]]) -> in
#
# Found very long example:
# Description length: 898 tokens
# Solution length: 434 tokens
# Combined length: 1346 tokens
#
# Description preview (first 100 chars):
# A message containing letters from `A-Z` can be **encoded** into numbers using the following mapping
# Solution preview (first 100 chars): class Solution:
#     def numDecodings(self, s: str) -> int:
#         mod = int(1e9 + 7)
#         n = le
#
# Found very long example:
# Description length: 743 tokens
# Solution length: 447 tokens
# Combined length: 1204 tokens
#
# Description preview (first 100 chars):
# You are asked to cut off all the trees in a forest for a golf event. The forest is represented as a
# Solution preview (first 100 chars): class Solution:
#     def cutOffTree(self, forest: List[List[int]]) -> int:
#         def f(i, j, x, y):
#
# Found very long example:
# Description length: 906 tokens
# Solution length: 262 tokens
# Combined length: 1182 tokens
#
# Description preview (first 100 chars):
# Given a list of `accounts` where each element `accounts[i]` is a list of strings, where the first e
# Solution preview (first 100 chars): class Solution:
#     def accountsMerge(self, accounts: List[List[str]]) -> List[List[str]]:
#         d
#
# Found very long example:
# Description length: 632 tokens
# Solution length: 372 tokens
# Combined length: 1018 tokens
#
# Description preview (first 100 chars):
# You are given an `n x n` `grid` representing a field of cherries, each cell is one of three possibl
# Solution preview (first 100 chars): class Solution:
#     def cherryPickup(self, grid: List[List[int]]) -> int:
#         n = len(grid)
#
#
# Found very long example:
# Description length: 682 tokens
# Solution length: 442 tokens
# Combined length: 1138 tokens
#
# Description preview (first 100 chars):
# You have a lock in front of you with 4 circular wheels. Each wheel has 10 slots: `'0', '1', '2', '3
# Solution preview (first 100 chars): class Solution:
#     def openLock(self, deadends: List[str], target: str) -> int:
#         def next(s)
#
# Found very long example:
# Description length: 614 tokens
# Solution length: 520 tokens
# Combined length: 1148 tokens
#
# Description preview (first 100 chars):
# You are given an `n x n` binary grid `board`. In each move, you can swap any two rows with each oth
# Solution preview (first 100 chars): class Solution:
#     def movesToChessboard(self, board: List[List[int]]) -> int:
#         def f(mask,
#
# Found very long example:
# Description length: 923 tokens
# Solution length: 257 tokens
# Combined length: 1194 tokens
#
# Description preview (first 100 chars):
# You are given an `n x n` integer matrix `board` where the cells are labeled from `1` to `n2` in a [
# Solution preview (first 100 chars): class Solution:
#     def snakesAndLadders(self, board: List[List[int]]) -> int:
#         def get(x):
#
#
# Found very long example:
# Description length: 896 tokens
# Solution length: 251 tokens
# Combined length: 1161 tokens
#
# Description preview (first 100 chars):
# You are given the `root` of a binary tree with `n` nodes, where each node is uniquely assigned a va
# Solution preview (first 100 chars): # Definition for a binary tree node.
# # class TreeNode:
# #     def __init__(self, val=0, left=None, ri
#
# Found very long example:
# Description length: 905 tokens
# Solution length: 263 tokens
# Combined length: 1182 tokens
#
# Description preview (first 100 chars):
# Given the `root` of a binary tree, calculate the **vertical order traversal** of the binary tree.
#
#
# Solution preview (first 100 chars): # Definition for a binary tree node.
# # class TreeNode:
# #     def __init__(self, val=0, left=None, ri
#
# Found very long example:
# Description length: 866 tokens
# Solution length: 218 tokens
# Combined length: 1098 tokens
#
# Description preview (first 100 chars):
# On a campus represented on the X-Y plane, there are `n` workers and `m` bikes, with `n <= m`.
#
#
# You
# Solution preview (first 100 chars): class Solution:
#     def assignBikes(
#         self, workers: List[List[int]], bikes: List[List[int]]
#
#
# Found very long example:
# Description length: 465 tokens
# Solution length: 948 tokens
# Combined length: 1427 tokens
#
# Description preview (first 100 chars):
# Design a data structure that efficiently finds the **majority element** of a given subarray.
#
#
# The
# Solution preview (first 100 chars): class Node:
#     __slots__ = ("l", "r", "x", "cnt")
#
#     def __init__(self):
#         self.l = self.r
#
# Found very long example:
# Description length: 617 tokens
# Solution length: 513 tokens
# Combined length: 1144 tokens
#
# Description preview (first 100 chars):
# There are `n` items each belonging to zero or one of `m` groups where `group[i]` is the group that
# Solution preview (first 100 chars): class Solution:
#     def sortItems(
#         self, n: int, m: int, group: List[int], beforeItems: List
#
# Found very long example:
# Description length: 656 tokens
# Solution length: 344 tokens
# Combined length: 1014 tokens
#
# Description preview (first 100 chars):
# You are given an `m x n` integer matrix `grid` where each cell is either `0` (empty) or `1` (obstac
# Solution preview (first 100 chars): class Solution:
#     def shortestPath(self, grid: List[List[int]], k: int) -> int:
#         m, n = len
#
# Found very long example:
# Description length: 829 tokens
# Solution length: 290 tokens
# Combined length: 1133 tokens
#
# Description preview (first 100 chars):
# You have `n` boxes labeled from `0` to `n - 1`. You are given four arrays: `status`, `candies`, `ke
# Solution preview (first 100 chars): class Solution:
#     def maxCandies(
#         self,
#         status: List[int],
#         candies: List[i
#
# Found very long example:
# Description length: 683 tokens
# Solution length: 484 tokens
# Combined length: 1181 tokens
#
# Description preview (first 100 chars):
# ![](https://fastly.jsdelivr.net/gh/doocs/leetcode@main/solution/1300-1399/1320.Minimum%20Distance%2
# Solution preview (first 100 chars): class Solution:
#     def minimumDistance(self, word: str) -> int:
#         def dist(a: int, b: int) ->
#
# Found very long example:
# Description length: 976 tokens
# Solution length: 137 tokens
# Combined length: 1127 tokens
#
# Description preview (first 100 chars):
# Given the array `restaurants` where  `restaurants[i] = [idi, ratingi, veganFriendlyi, pricei, dista
# Solution preview (first 100 chars): class Solution:
#     def filterRestaurants(
#         self,
#         restaurants: List[List[int]],
#
#
# Found very long example:
# Description length: 1066 tokens
# Solution length: 267 tokens
# Combined length: 1347 tokens
#
# Description preview (first 100 chars):
# Given an `m x n` grid. Each cell of the grid has a sign pointing to the next cell you should visit
# Solution preview (first 100 chars): class Solution:
#     def minCost(self, grid: List[List[int]]) -> int:
#         m, n = len(grid), len(g
#
# Found very long example:
# Description length: 842 tokens
# Solution length: 184 tokens
# Combined length: 1040 tokens
#
# Description preview (first 100 chars):
# Given a binary tree where each path going from the root to any leaf form a **valid sequence**, chec
# Solution preview (first 100 chars): # Definition for a binary tree node.
# # class TreeNode:
# #     def __init__(self, val=0, left=None, ri
#
# Found very long example:
# Description length: 832 tokens
# Solution length: 311 tokens
# Combined length: 1157 tokens
#
# Description preview (first 100 chars):
# You are given a `rows x cols` matrix `grid` representing a field of cherries where `grid[i][j]` rep
# Solution preview (first 100 chars): class Solution:
#     def cherryPickup(self, grid: List[List[int]]) -> int:
#         m, n = len(grid),
#
# Found very long example:
# Description length: 840 tokens
# Solution length: 213 tokens
# Combined length: 1067 tokens
#
# Description preview (first 100 chars):
# Given `2n` balls of `k` distinct colors. You will be given an integer array `balls` of size `k` whe
# Solution preview (first 100 chars): class Solution:
#     def getProbability(self, balls: List[int]) -> float:
#         @cache
#         def
#
# Found very long example:
# Description length: 932 tokens
# Solution length: 444 tokens
# Combined length: 1390 tokens
#
# Description preview (first 100 chars):
# Given a weighted undirected connected graph with `n` vertices numbered from `0` to `n - 1`, and an
# Solution preview (first 100 chars): class UnionFind:
#     def __init__(self, n):
#         self.p = list(range(n))
#         self.n = n
#
#
#
# Found very long example:
# Description length: 727 tokens
# Solution length: 322 tokens
# Combined length: 1063 tokens
#
# Description preview (first 100 chars):
# You are given an integer `n`, which indicates that there are `n` courses labeled from `1` to `n`. Y
# Solution preview (first 100 chars): class Solution:
#     def minNumberOfSemesters(self, n: int, relations: List[List[int]], k: int) -> in
#
# Found very long example:
# Description length: 876 tokens
# Solution length: 220 tokens
# Combined length: 1110 tokens
#
# Description preview (first 100 chars):
# Given a 2D array of characters `grid` of size `m x n`, you need to find if there exists any cycle c
# Solution preview (first 100 chars): class Solution:
#     def containsCycle(self, grid: List[List[str]]) -> bool:
#         def find(x):
#
#
# Found very long example:
# Description length: 986 tokens
# Solution length: 171 tokens
# Combined length: 1171 tokens
#
# Description preview (first 100 chars):
# You are given two arrays of positive integers, `boxes` and `warehouse`, representing the heights of
# Solution preview (first 100 chars): class Solution:
#     def maxBoxesInWarehouse(self, boxes: List[int], warehouse: List[int]) -> int:
#
#
# Found very long example:
# Description length: 843 tokens
# Solution length: 279 tokens
# Combined length: 1136 tokens
#
# Description preview (first 100 chars):
# Given an array `nums` that represents a permutation of integers from `1` to `n`. We are going to co
# Solution preview (first 100 chars): class Solution:
#     def numOfWays(self, nums: List[int]) -> int:
#         def dfs(nums):
#
#
# Found very long example:
# Description length: 901 tokens
# Solution length: 269 tokens
# Combined length: 1184 tokens
#
# Description preview (first 100 chars):
# You are given two arrays of positive integers, `boxes` and `warehouse`, representing the heights of
# Solution preview (first 100 chars): class Solution:
#     def maxBoxesInWarehouse(self, boxes: List[int], warehouse: List[int]) -> int:
#
#
# Found very long example:
# Description length: 732 tokens
# Solution length: 401 tokens
# Combined length: 1147 tokens
#
# Description preview (first 100 chars):
# You are given a `m x n` matrix `grid`. Initially, you are located at the top-left corner `(0, 0)`,
# Solution preview (first 100 chars): class Solution:
#     def maxProductPath(self, grid: List[List[int]]) -> int:
#         m, n = len(grid)
#
# Found very long example:
# Description length: 869 tokens
# Solution length: 192 tokens
# Combined length: 1075 tokens
#
# Description preview (first 100 chars):
# You are given an array `points`, an integer `angle`, and your `location`, where `location = [posx,
# Solution preview (first 100 chars): class Solution:
#     def visiblePoints(
#         self, points: List[List[int]], angle: int, location:
#
# Found very long example:
# Description length: 790 tokens
# Solution length: 251 tokens
# Combined length: 1055 tokens
#
# Description preview (first 100 chars):
# You are a hiker preparing for an upcoming hike. You are given `heights`, a 2D array of size `rows x
# Solution preview (first 100 chars): class Solution:
#     def minimumEffortPath(self, heights: List[List[int]]) -> int:
#         m, n = len
#
# Found very long example:
# Description length: 842 tokens
# Solution length: 241 tokens
# Combined length: 1097 tokens
#
# Description preview (first 100 chars):
# Given the `root` of a binary tree, return *the lowest common ancestor (LCA) of two given nodes,* `p
# Solution preview (first 100 chars): # Definition for a binary tree node.
# # class TreeNode:
# #     def __init__(self, x):
# #         self.v
#
# Found very long example:
# Description length: 1169 tokens
# Solution length: 254 tokens
# Combined length: 1437 tokens
#
# Description preview (first 100 chars):
# Given an integer array `instructions`, you are asked to create a sorted array from the elements in
# Solution preview (first 100 chars): class BinaryIndexedTree:
#     def __init__(self, n):
#         self.n = n
#         self.c = [0] * (n + 1
#
# Found very long example:
# Description length: 825 tokens
# Solution length: 178 tokens
# Combined length: 1017 tokens
#
# Description preview (first 100 chars):
# Given the `root` of a binary tree and an array of `TreeNode` objects `nodes`, return *the lowest co
# Solution preview (first 100 chars): # Definition for a binary tree node.
# # class TreeNode:
# #     def __init__(self, x):
# #         self.v
#
# Found very long example:
# Description length: 983 tokens
# Solution length: 291 tokens
# Combined length: 1288 tokens
#
# Description preview (first 100 chars):
# You have the task of delivering some boxes from storage to their ports using only one ship. However
# Solution preview (first 100 chars): class Solution:
#     def boxDelivering(
#         self, boxes: List[List[int]], portsCount: int, maxBox
#
# Found very long example:
# Description length: 820 tokens
# Solution length: 239 tokens
# Combined length: 1073 tokens
#
# Description preview (first 100 chars):
# You have a 2-D `grid` of size `m x n` representing a box, and you have `n` balls. The box is open o
# Solution preview (first 100 chars): class Solution:
#     def findBall(self, grid: List[List[int]]) -> List[int]:
#         def dfs(i: int,
#
# Found very long example:
# Description length: 870 tokens
# Solution length: 178 tokens
# Combined length: 1062 tokens
#
# Description preview (first 100 chars):
# You are given an array of `events` where `events[i] = [startDayi, endDayi, valuei]`. The `ith` even
# Solution preview (first 100 chars): class Solution:
#     def maxValue(self, events: List[List[int]], k: int) -> int:
#         events.sort(
#
# Found very long example:
# Description length: 755 tokens
# Solution length: 243 tokens
# Combined length: 1012 tokens
#
# Description preview (first 100 chars):
# You are given an integer matrix `isWater` of size `m x n` that represents a map of **land** and **w
# Solution preview (first 100 chars): class Solution:
#     def highestPeak(self, isWater: List[List[int]]) -> List[List[int]]:
#         m, n
#
# Found very long example:
# Description length: 924 tokens
# Solution length: 317 tokens
# Combined length: 1255 tokens
#
# Description preview (first 100 chars):
# There is a tree (i.e., a connected, undirected graph that has no cycles) consisting of `n` nodes nu
# Solution preview (first 100 chars): class Solution:
#     def getCoprimes(self, nums: List[int], edges: List[List[int]]) -> List[int]:
#
#
# Found very long example:
# Description length: 943 tokens
# Solution length: 134 tokens
# Combined length: 1091 tokens
#
# Description preview (first 100 chars):
# There is a **3 lane road** of length `n` that consists of `n + 1` **points** labeled from `0` to `n
# Solution preview (first 100 chars): class Solution:
#     def minSideJumps(self, obstacles: List[int]) -> int:
#         f = [1, 0, 1]
#
#
# Found very long example:
# Description length: 904 tokens
# Solution length: 178 tokens
# Combined length: 1096 tokens
#
# Description preview (first 100 chars):
# You are given `n`​​​​​​ tasks labeled from `0` to `n - 1` represented by a 2D integer array `tasks`
# Solution preview (first 100 chars): class Solution:
#     def getOrder(self, tasks: List[List[int]]) -> List[int]:
#         for i, task in
#
# Found very long example:
# Description length: 754 tokens
# Solution length: 369 tokens
# Combined length: 1137 tokens
#
# Description preview (first 100 chars):
# You are given a string `num`, representing a large integer, and an integer `k`.
#
#
# We call some inte
# Solution preview (first 100 chars): class Solution:
#     def getMinSwaps(self, num: str, k: int) -> int:
#         def next_permutation(num
#
# Found very long example:
# Description length: 768 tokens
# Solution length: 221 tokens
# Combined length: 1003 tokens
#
# Description preview (first 100 chars):
# You are given an `m x n` matrix of characters `box` representing a side-view of a box. Each cell of
# Solution preview (first 100 chars): class Solution:
#     def rotateTheBox(self, box: List[List[str]]) -> List[List[str]]:
#         m, n =
#
# Found very long example:
# Description length: 878 tokens
# Solution length: 234 tokens
# Combined length: 1126 tokens
#
# Description preview (first 100 chars):
# You are given an integer `hoursBefore`, the number of hours you have to travel to your meeting. To
# Solution preview (first 100 chars): class Solution:
#     def minSkips(self, dist: List[int], speed: int, hoursBefore: int) -> int:
#
#
# Found very long example:
# Description length: 892 tokens
# Solution length: 165 tokens
# Combined length: 1071 tokens
#
# Description preview (first 100 chars):
# You have `n` packages that you are trying to place in boxes, **one package in each box**. There are
# Solution preview (first 100 chars): class Solution:
#     def minWastedSpace(self, packages: List[int], boxes: List[List[int]]) -> int:
#
#
# Found very long example:
# Description length: 958 tokens
# Solution length: 121 tokens
# Combined length: 1093 tokens
#
# Description preview (first 100 chars):
# A **triplet** is an array of three integers. You are given a 2D integer array `triplets`, where `tr
# Solution preview (first 100 chars): class Solution:
#     def mergeTriplets(self, triplets: List[List[int]], target: List[int]) -> bool:
#
#
# Found very long example:
# Description length: 755 tokens
# Solution length: 334 tokens
# Combined length: 1103 tokens
#
# Description preview (first 100 chars):
# There is a tournament where `n` players are participating. The players are standing in a single row
# Solution preview (first 100 chars): class Solution:
#     def earliestAndLatest(
#         self, n: int, firstPlayer: int, secondPlayer: int
#
# Found very long example:
# Description length: 845 tokens
# Solution length: 195 tokens
# Combined length: 1054 tokens
#
# Description preview (first 100 chars):
# You are given an `m x n` integer matrix `points` (**0-indexed**). Starting with `0` points, you wan
# Solution preview (first 100 chars): class Solution:
#     def maxPoints(self, points: List[List[int]]) -> int:
#         n = len(points[0])
#
#
# Found very long example:
# Description length: 939 tokens
# Solution length: 357 tokens
# Combined length: 1310 tokens
#
# Description preview (first 100 chars):
# There is a **1-based** binary matrix where `0` represents land and `1` represents water. You are gi
# Solution preview (first 100 chars): class Solution:
#     def latestDayToCross(self, row: int, col: int, cells: List[List[int]]) -> int:
#
#
# Found very long example:
# Description length: 989 tokens
# Solution length: 227 tokens
# Combined length: 1230 tokens
#
# Description preview (first 100 chars):
# You are given a **0-indexed** `m x n` binary matrix `land` where a `0` represents a hectare of fore
# Solution preview (first 100 chars): class Solution:
#     def findFarmland(self, land: List[List[int]]) -> List[List[int]]:
#         m, n =
#
# Found very long example:
# Description length: 1205 tokens
# Solution length: 218 tokens
# Combined length: 1437 tokens
#
# Description preview (first 100 chars):
# A perfectly straight street is represented by a number line. The street has building(s) on it and i
# Solution preview (first 100 chars): class Solution:
#     def averageHeightOfBuildings(self, buildings: List[List[int]]) -> List[List[int]
#
# Found very long example:
# Description length: 1331 tokens
# Solution length: 208 tokens
# Combined length: 1553 tokens
#
# Description preview (first 100 chars):
# There is a network of `n` servers, labeled from `0` to `n - 1`. You are given a 2D integer array `e
# Solution preview (first 100 chars): class Solution:
#     def networkBecomesIdle(self, edges: List[List[int]], patience: List[int]) -> int
#
# Found very long example:
# Description length: 948 tokens
# Solution length: 259 tokens
# Combined length: 1221 tokens
#
# Description preview (first 100 chars):
# You are given an integer `n`, which indicates that there are `n` courses labeled from `1` to `n`. Y
# Solution preview (first 100 chars): class Solution:
#     def minimumTime(self, n: int, relations: List[List[int]], time: List[int]) -> in
#
# Found very long example:
# Description length: 887 tokens
# Solution length: 187 tokens
# Combined length: 1088 tokens
#
# Description preview (first 100 chars):
# You are given a string `sentence` containing words separated by spaces, and an integer `k`. Your ta
# Solution preview (first 100 chars): class Solution:
#     def minimumCost(self, sentence: str, k: int) -> int:
#         @cache
#         def
#
# Found very long example:
# Description length: 778 tokens
# Solution length: 278 tokens
# Combined length: 1070 tokens
#
# Description preview (first 100 chars):
# You have `n` tasks and `m` workers. Each task has a strength requirement stored in a **0-indexed**
# Solution preview (first 100 chars): class Solution:
#     def maxTaskAssign(
#         self, tasks: List[int], workers: List[int], pills: in
#
# Found very long example:
# Description length: 841 tokens
# Solution length: 175 tokens
# Combined length: 1030 tokens
#
# Description preview (first 100 chars):
# There is an `m x n` grid, where `(0, 0)` is the top-left cell and `(m - 1, n - 1)` is the bottom-ri
# Solution preview (first 100 chars): class Solution:
#     def minCost(
#         self,
#         startPos: List[int],
#         homePos: List[in
#
# Found very long example:
# Description length: 1247 tokens
# Solution length: 341 tokens
# Combined length: 1602 tokens
#
# Description preview (first 100 chars):
# A farmer has a **rectangular grid** of land with `m` rows and `n` columns that can be divided into
# Solution preview (first 100 chars): class Solution:
#     def countPyramids(self, grid: List[List[int]]) -> int:
#         m, n = len(grid),
#
# Found very long example:
# Description length: 914 tokens
# Solution length: 115 tokens
# Combined length: 1043 tokens
#
# Description preview (first 100 chars):
# You are given a **0-indexed** array `nums` of `n` integers, and an integer `k`.
#
#
# The **k-radius av
# Solution preview (first 100 chars): class Solution:
#     def getAverages(self, nums: List[int], k: int) -> List[int]:
#         s = 0
#
#
# Found very long example:
# Description length: 902 tokens
# Solution length: 298 tokens
# Combined length: 1214 tokens
#
# Description preview (first 100 chars):
# You are given an integer `n` indicating there are `n` people numbered from `0` to `n - 1`. You are
# Solution preview (first 100 chars): class Solution:
#     def findAllPeople(
#         self, n: int, meetings: List[List[int]], firstPerson:
#
# Found very long example:
# Description length: 661 tokens
# Solution length: 375 tokens
# Combined length: 1050 tokens
#
# Description preview (first 100 chars):
# You are given the `root` of a **binary tree** with `n` nodes. Each node is uniquely assigned a valu
# Solution preview (first 100 chars): # Definition for a binary tree node.
# # class TreeNode:
# #     def __init__(self, val=0, left=None, ri
#
# Found very long example:
# Description length: 909 tokens
# Solution length: 286 tokens
# Combined length: 1209 tokens
#
# Description preview (first 100 chars):
# You are given a list of bombs. The **range** of a bomb is defined as the area where its effect can
# Solution preview (first 100 chars): class Solution:
#     def maximumDetonation(self, bombs: List[List[int]]) -> int:
#         def check(i,
#
# Found very long example:
# Description length: 1009 tokens
# Solution length: 161 tokens
# Combined length: 1184 tokens
#
# Description preview (first 100 chars):
# Fruits are available at some positions on an infinite x-axis. You are given a 2D integer array `fru
# Solution preview (first 100 chars): class Solution:
#     def maxTotalFruits(self, fruits: List[List[int]], startPos: int, k: int) -> int:
#
# Found very long example:
# Description length: 878 tokens
# Solution length: 125 tokens
# Combined length: 1017 tokens
#
# Description preview (first 100 chars):
# You are given a **0-indexed** array `arr` consisting of `n` positive integers, and a positive integ
# Solution preview (first 100 chars): class Solution:
#     def kIncreasing(self, arr: List[int], k: int) -> int:
#         def lis(arr):
#
#
# Found very long example:
# Description length: 782 tokens
# Solution length: 280 tokens
# Combined length: 1076 tokens
#
# Description preview (first 100 chars):
# Alice had a **0-indexed** array `arr` consisting of `n` **positive** integers. She chose an arbitra
# Solution preview (first 100 chars): class Solution:
#     def recoverArray(self, nums: List[int]) -> List[int]:
#         nums.sort()
#
#
# Found very long example:
# Description length: 654 tokens
# Solution length: 432 tokens
# Combined length: 1100 tokens
#
# Description preview (first 100 chars):
# You are given an `m x n` binary matrix `grid` where each cell is either `0` (empty) or `1` (occupie
# Solution preview (first 100 chars): class Solution:
#     def possibleToStamp(
#         self, grid: List[List[int]], stampHeight: int, stam
#
# Found very long example:
# Description length: 813 tokens
# Solution length: 182 tokens
# Combined length: 1009 tokens
#
# Description preview (first 100 chars):
# You are given two **0-indexed** arrays of strings `startWords` and `targetWords`. Each string consi
# Solution preview (first 100 chars): class Solution:
#     def wordCount(self, startWords: List[str], targetWords: List[str]) -> int:
#
#
# Found very long example:
# Description length: 1031 tokens
# Solution length: 92 tokens
# Combined length: 1137 tokens
#
# Description preview (first 100 chars):
# You have `n` flower seeds. Every seed must be planted first before it can begin to grow, then bloom
# Solution preview (first 100 chars): class Solution:
#     def earliestFullBloom(self, plantTime: List[int], growTime: List[int]) -> int:
#
#
# Found very long example:
# Description length: 561 tokens
# Solution length: 457 tokens
# Combined length: 1032 tokens
#
# Description preview (first 100 chars):
# You are given integers `height` and `width` which specify the dimensions of a brick wall you are bu
# Solution preview (first 100 chars): class Solution:
#     def buildWall(self, height: int, width: int, bricks: List[int]) -> int:
#
#
# Found very long example:
# Description length: 798 tokens
# Solution length: 223 tokens
# Combined length: 1035 tokens
#
# Description preview (first 100 chars):
# You are given a **0-indexed** 2D integer array `tires` where `tires[i] = [fi, ri]` indicates that t
# Solution preview (first 100 chars): class Solution:
#     def minimumFinishTime(
#         self, tires: List[List[int]], changeTime: int, nu
#
# Found very long example:
# Description length: 837 tokens
# Solution length: 324 tokens
# Combined length: 1175 tokens
#
# Description preview (first 100 chars):
# Alice is a caretaker of `n` gardens and she wants to plant flowers to maximize the total beauty of
# Solution preview (first 100 chars): class Solution:
#     def maximumBeauty(
#         self, flowers: List[int], newFlowers: int, target: in
#
# Found very long example:
# Description length: 838 tokens
# Solution length: 161 tokens
# Combined length: 1013 tokens
#
# Description preview (first 100 chars):
# You are given a 2D integer array `rectangles` where `rectangles[i] = [li, hi]` indicates that `ith`
# Solution preview (first 100 chars): class Solution:
#     def countRectangles(
#         self, rectangles: List[List[int]], points: List[Lis
#
# Found very long example:
# Description length: 993 tokens
# Solution length: 663 tokens
# Combined length: 1670 tokens
#
# Description preview (first 100 chars):
# You are given a **0-indexed** 2D integer array `grid` of size `m x n` which represents a field. Eac
# Solution preview (first 100 chars): class Solution:
#     def maximumMinutes(self, grid: List[List[int]]) -> int:
#         def spread(q: De
#
# Found very long example:
# Description length: 846 tokens
# Solution length: 149 tokens
# Combined length: 1009 tokens
#
# Description preview (first 100 chars):
# You are given a **0-indexed** `m x n` integer matrix `grid` consisting of **distinct** integers fro
# Solution preview (first 100 chars): class Solution:
#     def minPathCost(self, grid: List[List[int]], moveCost: List[List[int]]) -> int:
#
#
# Found very long example:
# Description length: 924 tokens
# Solution length: 192 tokens
# Combined length: 1130 tokens
#
# Description preview (first 100 chars):
# You are given two integers `m` and `n` that represent the height and width of a rectangular piece o
# Solution preview (first 100 chars): class Solution:
#     def sellingWood(self, m: int, n: int, prices: List[List[int]]) -> int:
#         @
#
# Found very long example:
# Description length: 824 tokens
# Solution length: 185 tokens
# Combined length: 1023 tokens
#
# Description preview (first 100 chars):
# You are given two **0-indexed** integer arrays `nums1` and `nums2`, both of length `n`.
#
#
# You can c
# Solution preview (first 100 chars): class Solution:
#     def maximumsSplicedArray(self, nums1: List[int], nums2: List[int]) -> int:
#
#
# Found very long example:
# Description length: 729 tokens
# Solution length: 281 tokens
# Combined length: 1024 tokens
#
# Description preview (first 100 chars):
# You are given a **directed** graph of `n` nodes numbered from `0` to `n - 1`, where each node has *
# Solution preview (first 100 chars): class Solution:
#     def closestMeetingNode(self, edges: List[int], node1: int, node2: int) -> int:
#
#
# Found very long example:
# Description length: 953 tokens
# Solution length: 149 tokens
# Combined length: 1116 tokens
#
# Description preview (first 100 chars):
# A train line going through a city has two routes, the regular route and the express route. Both rou
# Solution preview (first 100 chars): class Solution:
#     def minimumCosts(
#         self, regular: List[int], express: List[int], expressC
#
# Found very long example:
# Description length: 904 tokens
# Solution length: 87 tokens
# Combined length: 1005 tokens
#
# Description preview (first 100 chars):
# You are given two 2D integer arrays, `items1` and `items2`, representing two sets of items. Each ar
# Solution preview (first 100 chars): class Solution:
#     def mergeSimilarItems(
#         self, items1: List[List[int]], items2: List[List[
#
# Found very long example:
# Description length: 497 tokens
# Solution length: 600 tokens
# Combined length: 1111 tokens
#
# Description preview (first 100 chars):
# You are given an integer array `nums` and an integer `k`.
#
#
# Find the longest subsequence of `nums`
# Solution preview (first 100 chars): class Node:
#     def __init__(self):
#         self.l = 0
#         self.r = 0
#         self.v = 0
#
#
# class
#
# Found very long example:
# Description length: 954 tokens
# Solution length: 232 tokens
# Combined length: 1200 tokens
#
# Description preview (first 100 chars):
# You are given a **0-indexed** integer array `costs` where `costs[i]` is the cost of hiring the `ith
# Solution preview (first 100 chars): class Solution:
#     def totalCost(self, costs: List[int], k: int, candidates: int) -> int:
#         q
#
# Found very long example:
# Description length: 707 tokens
# Solution length: 396 tokens
# Combined length: 1117 tokens
#
# Description preview (first 100 chars):
# You are given a positive integer `n` representing the number of nodes in an **undirected** graph. T
# Solution preview (first 100 chars): class Solution:
#     def magnificentSets(self, n: int, edges: List[List[int]]) -> int:
#         def df
#
# Found very long example:
# Description length: 794 tokens
# Solution length: 209 tokens
# Combined length: 1017 tokens
#
# Description preview (first 100 chars):
# You are given two **0-indexed** integer arrays `nums1` and `nums2`, of equal length `n`.
#
#
# In one o
# Solution preview (first 100 chars): class Solution:
#     def minimumTotalCost(self, nums1: List[int], nums2: List[int]) -> int:
#         a
#
# Found very long example:
# Description length: 978 tokens
# Solution length: 187 tokens
# Combined length: 1179 tokens
#
# Description preview (first 100 chars):
# You are given an integer array `nums` and an integer `k`.
#
#
# Split the array into some number of non
# Solution preview (first 100 chars): class Solution:
#     def minCost(self, nums: List[int], k: int) -> int:
#         @cache
#         def df
#
# Found very long example:
# Description length: 1013 tokens
# Solution length: 113 tokens
# Combined length: 1140 tokens
#
# Description preview (first 100 chars):
# You are given a **0-indexed** integer array `nums`.
#
#
# The **concatenation** of two numbers is the n
# Solution preview (first 100 chars): class Solution:
#     def findTheArrayConcVal(self, nums: List[int]) -> int:
#         ans = 0
#         i
#
# Found very long example:
# Description length: 1068 tokens
# Solution length: 303 tokens
# Combined length: 1385 tokens
#
# Description preview (first 100 chars):
# You are given a `m x n` matrix `grid` consisting of **non-negative** integers where `grid[row][col]
# Solution preview (first 100 chars): class Solution:
#     def minimumTime(self, grid: List[List[int]]) -> int:
#         if grid[0][1] > 1 a
#
# Found very long example:
# Description length: 871 tokens
# Solution length: 189 tokens
# Combined length: 1074 tokens
#
# Description preview (first 100 chars):
# There is a test that has `n` types of questions. You are given an integer `target` and a **0-indexe
# Solution preview (first 100 chars): class Solution:
#     def waysToReachTarget(self, target: int, types: List[List[int]]) -> int:
#
#
# Found very long example:
# Description length: 757 tokens
# Solution length: 382 tokens
# Combined length: 1153 tokens
#
# Description preview (first 100 chars):
# You are given a **0-indexed** `m x n` integer matrix `grid`. Your initial position is at the **top-
# Solution preview (first 100 chars): class Solution:
#     def minimumVisitedCells(self, grid: List[List[int]]) -> int:
#         m, n = len(
#
# Found very long example:
# Description length: 779 tokens
# Solution length: 234 tokens
# Combined length: 1027 tokens
#
# Description preview (first 100 chars):
# Given a **1-indexed** `m x n` integer matrix `mat`, you can select any cell in the matrix as your *
# Solution preview (first 100 chars): class Solution:
#     def maxIncreasingCells(self, mat: List[List[int]]) -> int:
#         m, n = len(ma
#
# Found very long example:
# Description length: 840 tokens
# Solution length: 187 tokens
# Combined length: 1041 tokens
#
# Description preview (first 100 chars):
# You are given a **0-indexed** 2D integer array `items` of length `n` and an integer `k`.
#
#
# `items[i
# Solution preview (first 100 chars): class Solution:
#     def findMaximumElegance(self, items: List[List[int]], k: int) -> int:
#         it
#
# Found very long example:
# Description length: 953 tokens
# Solution length: 536 tokens
# Combined length: 1503 tokens
#
# Description preview (first 100 chars):
# You are given an `n * m` **0-indexed** grid of string `land`. Right now, you are standing at the ce
# Solution preview (first 100 chars): class Solution:
#     def minimumSeconds(self, land: List[List[str]]) -> int:
#         m, n = len(land)
#
# Found very long example:
# Description length: 803 tokens
# Solution length: 207 tokens
# Combined length: 1024 tokens
#
# Description preview (first 100 chars):
# You are given a **0-indexed** integer array `nums` of length `n`.
#
#
#
# The numbers from `0` to `n
# Solution preview (first 100 chars): class Solution:
#     def minimumOperations(self, nums: List[int]) -> int:
#         f = [0] * 3
#
#
# Found very long example:
# Description length: 799 tokens
# Solution length: 273 tokens
# Combined length: 1086 tokens
#
# Description preview (first 100 chars):
# You are given a **0-indexed** integer array `receiver` of length `n` and an integer `k`.
#
#
# There ar
# Solution preview (first 100 chars): class Solution:
#     def getMaxFunctionValue(self, receiver: List[int], k: int) -> int:
#         n, m
#
# Found very long example:
# Description length: 871 tokens
# Solution length: 391 tokens
# Combined length: 1276 tokens
#
# Description preview (first 100 chars):
# There is an undirected tree with `n` nodes labeled from `1` to `n`. You are given the integer `n` a
# Solution preview (first 100 chars): class Solution:
#     def countPaths(self, n: int, edges: List[List[int]]) -> int:
#         def mul(x,
#
# Found very long example:
# Description length: 923 tokens
# Solution length: 229 tokens
# Combined length: 1166 tokens
#
# Description preview (first 100 chars):
# Alice and Bob each have a **lexicographically sorted** array of strings named `a` and `b` respectiv
# Solution preview (first 100 chars): class Solution:
#     def canAliceWin(self, a: List[str], b: List[str]) -> bool:
#         i, j, k = 1,
#
# Found very long example:
# Description length: 841 tokens
# Solution length: 283 tokens
# Combined length: 1138 tokens
#
# Description preview (first 100 chars):
# You are given an integer `n`, a **0-indexed** string array `words`, and a **0-indexed** array `grou
# Solution preview (first 100 chars): class Solution:
#     def getWordsInLongestSubsequence(
#         self, n: int, words: List[str], groups
#
# Found very long example:
# Description length: 678 tokens
# Solution length: 343 tokens
# Combined length: 1035 tokens
#
# Description preview (first 100 chars):
# Given a string `s` and an integer `k`, partition `s` into `k` **substrings** such that the sum of t
# Solution preview (first 100 chars): class Solution:
#     def minimumChanges(self, s: str, k: int) -> int:
#         n = len(s)
#         g =
#
# Found very long example:
# Description length: 769 tokens
# Solution length: 306 tokens
# Combined length: 1089 tokens
#
# Description preview (first 100 chars):
# You are given two integers `n` and `m` which represent the size of a **1-indexed** grid. You are al
# Solution preview (first 100 chars): class Solution:
#     def numberOfWays(
#         self, n: int, m: int, k: int, source: List[int], dest:
#
# Found very long example:
# Description length: 977 tokens
# Solution length: 214 tokens
# Combined length: 1205 tokens
#
# Description preview (first 100 chars):
# There is an undirected tree with `n` nodes labeled from `0` to `n - 1`, and rooted at node `0`. You
# Solution preview (first 100 chars): class Solution:
#     def maximumScoreAfterOperations(
#         self, edges: List[List[int]], values: L
#
# Found very long example:
# Description length: 626 tokens
# Solution length: 429 tokens
# Combined length: 1069 tokens
#
# Description preview (first 100 chars):
# You are given a **0-indexed** integer array `nums`. A pair of integers `x` and `y` is called a **st
# Solution preview (first 100 chars): class Trie:
#     __slots__ = ("children", "cnt")
#
#     def __init__(self):
#         self.children: List
#
# Found very long example:
# Description length: 1054 tokens
# Solution length: 145 tokens
# Combined length: 1213 tokens
#
# Description preview (first 100 chars):
# You are given a 2D **0-indexed** array of strings, `access_times`, with size `n`. For each `i` wher
# Solution preview (first 100 chars): class Solution:
#     def findHighAccessEmployees(self, access_times: List[List[str]]) -> List[str]:
#
#
# Found very long example:
# Description length: 861 tokens
# Solution length: 183 tokens
# Combined length: 1058 tokens
#
# Description preview (first 100 chars):
# You are given two **0-indexed** integer arrays, `nums1` and `nums2`, both having length `n`.
#
#
# You
# Solution preview (first 100 chars): class Solution:
#     def minOperations(self, nums1: List[int], nums2: List[int]) -> int:
#         def
#
# Found very long example:
# Description length: 681 tokens
# Solution length: 432 tokens
# Combined length: 1127 tokens
#
# Description preview (first 100 chars):
# You are given a **0-indexed** integer array `nums`. A pair of integers `x` and `y` is called a **st
# Solution preview (first 100 chars): class Trie:
#     __slots__ = ("children", "cnt")
#
#     def __init__(self):
#         self.children: List
#
# Found very long example:
# Description length: 900 tokens
# Solution length: 441 tokens
# Combined length: 1355 tokens
#
# Description preview (first 100 chars):
# You are given a **0-indexed** array `heights` of positive integers, where `heights[i]` represents t
# Solution preview (first 100 chars): class BinaryIndexedTree:
#     __slots__ = ["n", "c"]
#
#     def __init__(self, n: int):
#         self.n
#
# Found very long example:
# Description length: 1288 tokens
# Solution length: 176 tokens
# Combined length: 1478 tokens
#
# Description preview (first 100 chars):
# There is a grid with `n + 2` **horizontal** bars and `m + 2` **vertical** bars, and initially conta
# Solution preview (first 100 chars): class Solution:
#     def maximizeSquareHoleArea(
#         self, n: int, m: int, hBars: List[int], vBar

# %%
# Calculate statistics
print("\nToken Length Statistics:")
print("\nDescription Lengths:")
print(f"Mean: {np.mean(desc_lengths):.1f}")
print(f"Median: {np.median(desc_lengths):.1f}")
print(f"Max: {np.max(desc_lengths)}")
print(f"95th percentile: {np.percentile(desc_lengths, 95):.1f}")

print("\nSolution Lengths:")
print(f"Mean: {np.mean(soln_lengths):.1f}")
print(f"Median: {np.median(soln_lengths):.1f}")
print(f"Max: {np.max(soln_lengths)}")
print(f"95th percentile: {np.percentile(soln_lengths, 95):.1f}")

print("\nCombined Lengths (with prompt format):")
print(f"Mean: {np.mean(combined_lengths):.1f}")
print(f"Median: {np.median(combined_lengths):.1f}")
print(f"Max: {np.max(combined_lengths)}")
print(f"95th percentile: {np.percentile(combined_lengths, 95):.1f}")

# Print length distribution
print("\nLength Distribution (Combined):")
percentiles = [50, 75, 90, 95, 99, 100]
for p in percentiles:
    print(f"{p}th percentile: {np.percentile(combined_lengths, p):.1f}")
# Out:
# Token Length Statistics:
#
# Description Lengths:
# Mean: 584.6
# Median: 535.0
# Max: 2274
# 95th percentile: 1058.0
#
# Solution Lengths:
# Mean: 165.3
# Median: 148.0
# Max: 948
# 95th percentile: 334.3
#
# Combined Lengths (with prompt format):
# Mean: 763.9
# Median: 708.0
# Max: 2561
# 95th percentile: 1344.1
#
# Length Distribution (Combined):
# 50th percentile: 708.0
# 75th percentile: 918.2
# 90th percentile: 1147.1
# 95th percentile: 1344.1
# 99th percentile: 1653.0
# 100th percentile: 2561.0
